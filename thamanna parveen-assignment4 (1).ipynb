# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset into python environment

# %%
data=pd.read_csv('titanic_dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# #  Make ‘PassengerId’ as the index column

# %%
data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# 30                  0       3
# ...

# %% [markdown]
# # basic details of the dataset

# %%
data.shape
# Out:
# (850, 11)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # missing values present in all the columns in the dataset

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'].nunique()
# Out:
# 88

# %%
median_age=data['Age'].median(0)

# %%
median_age
# Out:
# 28.0

# %%
data['Age'].fillna(median_age)
data['Age']=data['Age'].fillna(median_age)

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Cabin'].nunique()
# Out:
# 147

# %%
data['Cabin'].value_counts()
# Out:
# G6             4
# C23 C25 C27    4
# B96 B98        4
# D              3
# E101           3
# F33            3
# F2             3
# C22 C26        3
# B49            2
# E121           2
# C123           2
# C93            2
# E25            2
# E33            2
# D36            2
# C2             2
# D17            2
# B35            2
# E67            2
# D26            2
# E8             2
# C78            2
# B51 B53 B55    2
# B5             2
# D33            2
# C92            2
# B77            2
# B58 B60        2
# B22            2
# B28            2
#               ..
# E10            1
# B37            1
# D11            1
# B38            1
# C95            1
# C62 C64        1
# F G63          1
# B39            1
# C106           1
# C49            1
# B86            1
# D48            1
# E40            1
# D49            1
# D9             1
# C32            1
# A20            1
# D6             1
# B30            1
# C90            1
# C101           1
# ...

# %%
data1=data.drop('Cabin',axis=1)

# %%
data=data1.dropna()

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # outliers

# %%
plt.boxplot(data['Pclass'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f61e0cea90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f620125470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f61e0cebe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6200f4da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6200f48d0>],
#  'means': []}

# %%
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f620809b00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f620809f28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6208096a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6208127f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f620812b38>],
#  'means': []}

# %%
out_index=np.where(data['Age']>55)
print(out_index)
# Out:
# (array([ 11,  33,  54,  93,  95, 115, 151, 169, 173, 194, 231, 251, 267,
#        274, 279, 325, 365, 437, 455, 466, 482, 486, 492, 544, 554, 569,
#        586, 624, 625, 629, 646, 658, 671, 683, 693, 744, 771, 849, 877],
#       dtype=int64),)

# %%
data=data.drop(out_index[0])
data.shape
# Out:
# (850, 11)

# %%
plt.boxplot(data['SibSp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f621a96748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f621a96da0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f621a96320>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f621aa0470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f621aa07b8>],
#  'means': []}

# %%
out_index=np.where(data['SibSp']>2)
print(out_index)
# Out:
# (array([  7,  15,  23,  26,  48,  56,  59,  64,  67,  81,  84, 112, 151,
#        156, 162, 166, 170, 172, 190, 218, 221, 248, 253, 263, 308, 324,
#        356, 368, 391, 459, 463, 517, 518, 603, 611, 651, 690, 749, 754,
#        775, 781, 786, 807, 810, 823], dtype=int64),)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
X=data.iloc[:,[5,7]]
y=data.iloc[:,[1]]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y, random_state=50)

# %%
X_train.head()
# Out:
#       Age  Parch
# 302  19.0      0
# 464  28.0      0
# 621  42.0      0
# 723  50.0      0
# 227  20.5      0

# %%
scaler=MinMaxScaler().fit(X_train)
# Out:
# C:\Users\thama\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
print(scaler)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.data_min_
# Out:
# array([0.42, 0.  ])

# %%
scaler.data_max_
# Out:
# array([80.,  6.])

# %%
scaler.transform(X_train)
# Out:
# array([[0.23347575, 0.        ],
#        [0.34656949, 0.        ],
#        [0.52249309, 0.        ],
#        ...,
#        [0.88062327, 0.        ],
#        [0.19577783, 0.        ],
#        [0.33400352, 0.        ]])

# %%
scaler=MinMaxScaler().fit(X_test)
# Out:
# C:\Users\thama\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
scaler
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
